# %% [markdown]
# # What's the Weather Like?
#
#
#
# #### Analysis
# * Insert Here
#
# #### Observable Trends
# * After collecting weather data randomly from 559 cities around the world using the OpenWeatherMap API, the data illustrated maximum temperature (°F), humidity (%), cloudiness (%) and wind speed (mph) with the corresponding city with respect to its Latitude. As expected, temperatures tend to be higher closer to the Equator and are significantly lower in the Northern Hemisphere at this time of the year (March 2020).

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json

# Import API key
from api_keys import api_key
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

units = "imperial"

# define url
query_url = f"http://api.openweathermap.org/data/2.5/weather?appid={api_key}&units={units}&q="

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 607

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#set lists for data to be appended into
city_name = []
cloudiness = []
date = []
humidity = []
latitude = []
longitude = []
max_temperature = []
wind_speed = []
country = []

#set counter for nubmer of cities processed
processing_record = 1

print("----Begin Process----")
# create loop for dataframe columns using the response and api target url
for city in cities:

# Exception Handling
    try:
        response = requests.get(query_url + city).json()
        city_name.append(response["name"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        latitude.append(response["coord"]["lat"])
        longitude.append(response["coord"]["lon"])
        max_temperature.append(response["main"]["temp_max"])
        humidity.append(response["main"]["humidity"])
        cloudiness.append(response["clouds"]["all"])
        wind_speed.append(response["wind"]["speed"])
        city_record = response["name"]
        print(f"Processing Record {processing_record} | {city_record}")
        
        # Increase Processing Record Counter by 1 For Each Loop
        processing_record += 1
        
    except:
        print("City not found. Skipping...") 
    continue
print("----Data Retrieval Complete----")
# Out:
# ----Begin Process----
# Processing Record 1 | Lata
# Processing Record 2 | Bluff
# City not found. Skipping...
# Processing Record 3 | Thompson
# Processing Record 4 | Hilo
# Processing Record 5 | Jamestown
# Processing Record 6 | Guadalajara
# Processing Record 7 | Damāvand
# Processing Record 8 | Cidreira
# Processing Record 9 | Mataura
# Processing Record 10 | Hithadhoo
# Processing Record 11 | Cape Town
# Processing Record 12 | Calamar
# Processing Record 13 | Ribeira Grande
# Processing Record 14 | Dikson
# Processing Record 15 | Çermik
# Processing Record 16 | Rikitea
# Processing Record 17 | Mount Isa
# Processing Record 18 | Salinópolis
# Processing Record 19 | Severo-Kuril'sk
# Processing Record 20 | Yellowknife
# Processing Record 21 | Bredasdorp
# Processing Record 22 | Sikonge
# Processing Record 23 | Eureka
# Processing Record 24 | Cabo San Lucas
# City not found. Skipping...
# Processing Record 25 | Castro
# Processing Record 26 | Norman Wells
# Processing Record 27 | Espinosa
# Processing Record 28 | Tuktoyaktuk
# City not found. Skipping...
# Processing Record 29 | Puerto Peñasco
# Processing Record 30 | East London
# Processing Record 31 | Saskylakh
# Processing Record 32 | Batagay-Alyta
# Processing Record 33 | Hobart
# Processing Record 34 | Arraial do Cabo
# City not found. Skipping...
# Processing Record 35 | Punta Arenas
# Processing Record 36 | Alofi
# Processing Record 37 | Husavik
# Processing Record 38 | Yumen
# Processing Record 39 | Puerto Ayora
# City not found. Skipping...
# Processing Record 40 | Camacha
# City not found. Skipping...
# Processing Record 41 | Ushuaia
# Processing Record 42 | Geraldton
# Processing Record 43 | Busselton
# Processing Record 44 | Cockburn Town
# Processing Record 45 | Kahului
# Processing Record 46 | Kattivākkam
# Processing Record 47 | New Norfolk
# Processing Record 48 | Asău
# Processing Record 49 | Shingū
# Processing Record 50 | Cabinda
# Processing Record 51 | Palmer
# Processing Record 52 | Port Alfred
# Processing Record 53 | Kirakira
# City not found. Skipping...
# Processing Record 54 | Vaini
# Processing Record 55 | Albany
# Processing Record 56 | Torbay
# City not found. Skipping...
# Processing Record 57 | Oranjestad
# Processing Record 58 | Likhoslavl'
# Processing Record 59 | Saint-Philippe
# City not found. Skipping...
# Processing Record 60 | Mpulungu
# Processing Record 61 | Zarubino
# Processing Record 62 | Polunochnoye
# Processing Record 63 | Ponta do Sol
# City not found. Skipping...
# Processing Record 64 | Veinticinco de Mayo
# Processing Record 65 | Mareeba
# Processing Record 66 | Timizart
# Processing Record 67 | Genhe
# Processing Record 68 | Pevek
# City not found. Skipping...
# Processing Record 69 | Flinders
# Processing Record 70 | Barrow
# Processing Record 71 | Hermanus
# City not found. Skipping...
# Processing Record 72 | Yunyang
# Processing Record 73 | Kalmunai
# Processing Record 74 | Lima
# Processing Record 75 | Grand Gaube
# Processing Record 76 | Hambantota
# Processing Record 77 | Murray Bridge
# Processing Record 78 | Esperance
# Processing Record 79 | Inongo
# City not found. Skipping...
# Processing Record 80 | Santa Cruz Cabrália
# Processing Record 81 | Sola
# Processing Record 82 | Saint-Ambroise
# Processing Record 83 | Atuona
# Processing Record 84 | Mago
# Processing Record 85 | Sur
# Processing Record 86 | Saint Anthony
# Processing Record 87 | Den Helder
# Processing Record 88 | Dalhousie
# Processing Record 89 | Xai-Xai
# Processing Record 90 | Ust'-Kut
# Processing Record 91 | Vilhena
# Processing Record 92 | Ndélé
# Processing Record 93 | Bambous Virieux
# Processing Record 94 | Akriní
# Processing Record 95 | Upernavik
# Processing Record 96 | Qaanaaq
# Processing Record 97 | Puerto Cabezas
# Processing Record 98 | San Luis
# Processing Record 99 | Tongchuanshi
# Processing Record 100 | Khatanga
# Processing Record 101 | Faya
# Processing Record 102 | Chul'man
# Processing Record 103 | Kahama
# Processing Record 104 | Carnarvon
# Processing Record 105 | Iturama
# Processing Record 106 | Artvin Province
# Processing Record 107 | Bethel
# City not found. Skipping...
# Processing Record 108 | Tuatapere
# Processing Record 109 | Chui
# Processing Record 110 | San Cristobal
# Processing Record 111 | Tasiilaq
# Processing Record 112 | Luwuk
# Processing Record 113 | Tucumã
# Processing Record 114 | Flin Flon
# Processing Record 115 | Changde
# Processing Record 116 | Chokurdakh
# Processing Record 117 | Grindavik
# City not found. Skipping...
# Processing Record 118 | Hervey Bay
# Processing Record 119 | San Lorenzo
# Processing Record 120 | Provideniya
# Processing Record 121 | Lorengau
# Processing Record 122 | Berlevåg
# Processing Record 123 | Āsosa
# Processing Record 124 | Salalah
# City not found. Skipping...
# Processing Record 125 | Namatanai
# Processing Record 126 | Leningradskiy
# Processing Record 127 | Mehamn
# Processing Record 128 | Kungurtug
# Processing Record 129 | Tel Aviv-Yafo
# Processing Record 130 | Vrindāvan
# Processing Record 131 | Inhambane
# Processing Record 132 | Mar del Plata
# Processing Record 133 | San Quintín
# Processing Record 134 | Deputatsky
# Processing Record 135 | Abu Kamal
# Processing Record 136 | Souillac
# Processing Record 137 | Bathsheba
# Processing Record 138 | San Giovanni Lupatoto
# Processing Record 139 | Epe
# Processing Record 140 | Santo Tomas
# Processing Record 141 | Lawton
# City not found. Skipping...
# Processing Record 142 | Chemainus
# Processing Record 143 | Korla
# City not found. Skipping...
# Processing Record 144 | Ajdabiya
# Processing Record 145 | Aklavik
# Processing Record 146 | Hofn
# Processing Record 147 | Sulina
# Processing Record 148 | Pontes e Lacerda
# Processing Record 149 | Hendek
# Processing Record 150 | Fukuechō
# Processing Record 151 | Oussouye
# Processing Record 152 | Alyangula
# Processing Record 153 | Guerrero Negro
# City not found. Skipping...
# Processing Record 154 | Katsuura
# Processing Record 155 | Kaitangata
# Processing Record 156 | San Vicente
# Processing Record 157 | Paracuru
# Processing Record 158 | Mayo
# Processing Record 159 | Vardø
# Processing Record 160 | Port Elizabeth
# Processing Record 161 | Soyo
# Processing Record 162 | Erdenet
# Processing Record 163 | Koygorodok
# Processing Record 164 | Dingle
# Processing Record 165 | Cayenne
# Processing Record 166 | Avarua
# Processing Record 167 | Acapulco de Juárez
# Processing Record 168 | Panguna
# Processing Record 169 | Vestmanna
# Processing Record 170 | Constitución
# Processing Record 171 | Kapaa
# Processing Record 172 | Lichuan
# Processing Record 173 | Liyang
# Processing Record 174 | Viedma
# City not found. Skipping...
# Processing Record 175 | Pachino
# Processing Record 176 | Saint George
# Processing Record 177 | Bilibino
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 178 | Yerbogachën
# Processing Record 179 | Lebu
# Processing Record 180 | Vila Franca do Campo
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 181 | Butaritari
# Processing Record 182 | Peresichna
# City not found. Skipping...
# Processing Record 183 | San Jose
# City not found. Skipping...
# Processing Record 184 | Phan Thiet
# Processing Record 185 | Kiunga
# Processing Record 186 | Tsumeb
# Processing Record 187 | Huron
# Processing Record 188 | Hong Kong
# Processing Record 189 | Kiama
# Processing Record 190 | Salinas
# Processing Record 191 | Inzer
# Processing Record 192 | Barra de Tecoanapa
# Processing Record 193 | Aksu
# Processing Record 194 | Chimoré
# Processing Record 195 | Clyde River
# Processing Record 196 | Lethem
# Processing Record 197 | Leshukonskoye
# Processing Record 198 | Tiksi
# Processing Record 199 | Alta Floresta
# Processing Record 200 | Cobija
# Processing Record 201 | Hay River
# Processing Record 202 | Vao
# Processing Record 203 | Tabou
# Processing Record 204 | Fomboni
# Processing Record 205 | Kayes
# Processing Record 206 | Lompoc
# City not found. Skipping...
# Processing Record 207 | Pointe-Noire
# Processing Record 208 | Scottsbluff
# Processing Record 209 | Goulburn
# Processing Record 210 | Nikolskoye
# Processing Record 211 | Yanam
# Processing Record 212 | Baijiantan
# Processing Record 213 | Arica
# Processing Record 214 | Wattegama
# Processing Record 215 | Tura
# Processing Record 216 | Isla
# Processing Record 217 | Sampit
# Processing Record 218 | Bahía Blanca
# Processing Record 219 | Taoudenni
# Processing Record 220 | San Miguel de Cozumel
# Processing Record 221 | Nyurba
# Processing Record 222 | Sitka
# Processing Record 223 | Chardara
# Processing Record 224 | Labuhan
# Processing Record 225 | Chapais
# Processing Record 226 | Beringovskiy
# Processing Record 227 | Matagami
# Processing Record 228 | Banda Aceh
# Processing Record 229 | Lensk
# Processing Record 230 | Azul
# Processing Record 231 | Birin
# City not found. Skipping...
# Processing Record 232 | Monroe
# City not found. Skipping...
# Processing Record 233 | Tokur
# Processing Record 234 | Frontera
# Processing Record 235 | Saint Paul Harbor
# Processing Record 236 | Tanete
# Processing Record 237 | Khovd
# Processing Record 238 | Mahibadhoo
# Processing Record 239 | Taltal
# Processing Record 240 | Pisco
# Processing Record 241 | George
# Processing Record 242 | High Level
# Processing Record 243 | Totness
# Processing Record 244 | Klaksvík
# Processing Record 245 | Røros
# Processing Record 246 | Esim
# Processing Record 247 | Touros
# Processing Record 248 | Bengkulu
# Processing Record 249 | Ayan
# Processing Record 250 | Sobolevo
# Processing Record 251 | Emerald
# Processing Record 252 | Port Pirie
# Processing Record 253 | Longyearbyen
# Processing Record 254 | Qaqortoq
# Processing Record 255 | Ancud
# City not found. Skipping...
# Processing Record 256 | Nara
# Processing Record 257 | Khani
# Processing Record 258 | Vanimo
# Processing Record 259 | San Fernando del Valle de Catamarca
# Processing Record 260 | Gibara
# Processing Record 261 | Bellevue
# City not found. Skipping...
# Processing Record 262 | Slobodskoy
# Processing Record 263 | Port Lincoln
# Processing Record 264 | Székesfehérvár
# Processing Record 265 | Benalla
# Processing Record 266 | George Town
# Processing Record 267 | Stephenville
# Processing Record 268 | Lagoa
# Processing Record 269 | Richards Bay
# Processing Record 270 | Ust-Tsilma
# Processing Record 271 | Makkah al Mukarramah
# Processing Record 272 | Río Gallegos
# Processing Record 273 | Konotop
# Processing Record 274 | Mahébourg
# Processing Record 275 | Fairbanks
# City not found. Skipping...
# Processing Record 276 | Sayyan
# Processing Record 277 | Kichera
# Processing Record 278 | Gravelbourg
# Processing Record 279 | Lüderitz
# Processing Record 280 | Mackay
# Processing Record 281 | Muros
# Processing Record 282 | Laurel
# Processing Record 283 | Canutama
# Processing Record 284 | Sigli
# Processing Record 285 | Kilindoni
# Processing Record 286 | Pangnirtung
# Processing Record 287 | Kavaratti
# Processing Record 288 | Saldanha
# Processing Record 289 | Port Hardy
# Processing Record 290 | Stornoway
# Processing Record 291 | Sweetwater
# Processing Record 292 | Iqaluit
# Processing Record 293 | Balotra
# Processing Record 294 | Misratah
# Processing Record 295 | Khandyga
# Processing Record 296 | Tautira
# Processing Record 297 | Karmaskaly
# City not found. Skipping...
# Processing Record 298 | Teguise
# Processing Record 299 | Hamilton
# Processing Record 300 | Padang
# Processing Record 301 | Dire Dawa
# Processing Record 302 | Copiapó
# Processing Record 303 | Havre-St-Pierre
# Processing Record 304 | Necochea
# Processing Record 305 | Solnechnyy
# Processing Record 306 | Amapá
# Processing Record 307 | Tompa
# Processing Record 308 | Montecristo
# Processing Record 309 | Rabo de Peixe
# Processing Record 310 | Aras
# Processing Record 311 | Idrinskoye
# Processing Record 312 | Fort Morgan
# Processing Record 313 | Springfield
# Processing Record 314 | Dongxing
# Processing Record 315 | Komsomol'skoye
# Processing Record 316 | Nepomuceno
# City not found. Skipping...
# Processing Record 317 | Bourail
# Processing Record 318 | Częstochowa
# Processing Record 319 | Anori
# Processing Record 320 | Havøysund
# Processing Record 321 | Verkh-Usugli
# Processing Record 322 | Chāndor
# Processing Record 323 | Sosnovo-Ozerskoye
# Processing Record 324 | Talnakh
# City not found. Skipping...
# Processing Record 325 | Nantucket
# Processing Record 326 | Dunedin
# Processing Record 327 | Kieta
# Processing Record 328 | Estrela
# City not found. Skipping...
# Processing Record 329 | Belmonte
# Processing Record 330 | Ialibu
# Processing Record 331 | Ahipara
# Processing Record 332 | Shunyi
# Processing Record 333 | Quatá
# Processing Record 334 | Pallapatti
# Processing Record 335 | Taunsa
# Processing Record 336 | Virginia Beach
# City not found. Skipping...
# Processing Record 337 | Bako
# Processing Record 338 | Southbridge
# Processing Record 339 | La Tuque
# Processing Record 340 | Antofagasta
# Processing Record 341 | Nhulunbuy
# Processing Record 342 | Ilulissat
# Processing Record 343 | Imbituba
# Processing Record 344 | Koslan
# Processing Record 345 | Fort Nelson
# Processing Record 346 | Kingman
# Processing Record 347 | Isil'kul'
# Processing Record 348 | Waverly
# Processing Record 349 | Arlit
# Processing Record 350 | Biak
# Processing Record 351 | Sinnamary
# Processing Record 352 | Mandera
# Processing Record 353 | Digha
# Processing Record 354 | Coahuayana Viejo
# Processing Record 355 | Jinka
# Processing Record 356 | Arkhipo-Osipovka
# Processing Record 357 | San Patricio
# Processing Record 358 | Anadyr
# Processing Record 359 | Isangel
# Processing Record 360 | São Filipe
# City not found. Skipping...
# Processing Record 361 | Port Talbot
# Processing Record 362 | Inhambupe
# Processing Record 363 | Kiryat Gat
# Processing Record 364 | Hasaki
# Processing Record 365 | Yeppoon
# Processing Record 366 | Igarka
# Processing Record 367 | Talara
# Processing Record 368 | Gornopravdinsk
# Processing Record 369 | Paravola
# Processing Record 370 | Kavieng
# Processing Record 371 | Churapcha
# Processing Record 372 | Nha Trang
# Processing Record 373 | Yar-Sale
# Processing Record 374 | Henties Bay
# Processing Record 375 | Kaili
# Processing Record 376 | Santiago
# Processing Record 377 | Orodara
# Processing Record 378 | Lucapa
# Processing Record 379 | Gouré
# Processing Record 380 | Karaton
# Processing Record 381 | Wanning
# Processing Record 382 | Moindou
# Processing Record 383 | Mosquera
# Processing Record 384 | Isabela
# Processing Record 385 | Tiarei
# City not found. Skipping...
# Processing Record 386 | Nanortalik
# Processing Record 387 | Samarai
# Processing Record 388 | Pineville
# Processing Record 389 | Tessalit
# Processing Record 390 | Rawson
# Processing Record 391 | Gizo Government Station
# Processing Record 392 | Coquimbo
# Processing Record 393 | Santa Rosa
# Processing Record 394 | Dubbo
# Processing Record 395 | Akdağmadeni
# Processing Record 396 | São João da Barra
# Processing Record 397 | Löningen
# City not found. Skipping...
# Processing Record 398 | Lavrentiya
# Processing Record 399 | Wollongong
# Processing Record 400 | Sinegor'ye
# City not found. Skipping...
# Processing Record 401 | The Valley
# Processing Record 402 | Codrington
# Processing Record 403 | College
# Processing Record 404 | Evensk
# Processing Record 405 | Roald
# Processing Record 406 | Ribas do Rio Pardo
# Processing Record 407 | Farafangana
# Processing Record 408 | Rio Grande
# Processing Record 409 | Kulhudhuffushi
# Processing Record 410 | Salimpur
# Processing Record 411 | Ambilobe
# Processing Record 412 | Saint-Pierre
# Processing Record 413 | Bereşti-Sat
# Processing Record 414 | Shalyhyne
# Processing Record 415 | Chabahar
# Processing Record 416 | Price
# Processing Record 417 | Neryungri
# Processing Record 418 | Salisbury
# Processing Record 419 | Upata
# Processing Record 420 | Luau
# Processing Record 421 | Ürümqi
# Processing Record 422 | Mayor Pablo Lagerenza
# Processing Record 423 | Faanui
# Processing Record 424 | Westport
# Processing Record 425 | City of San Pedro
# Processing Record 426 | Paamiut
# Processing Record 427 | Kaduqli
# Processing Record 428 | Sabang
# Processing Record 429 | Mossamedes
# Processing Record 430 | Baykit
# Processing Record 431 | Tomatlán
# Processing Record 432 | Digoin
# Processing Record 433 | Kruisfontein
# Processing Record 434 | Shwebo
# Processing Record 435 | Yangi Marg`ilon
# Processing Record 436 | Goryachegorsk
# Processing Record 437 | Laas
# Processing Record 438 | Oudtshoorn
# Processing Record 439 | Cherskiy
# Processing Record 440 | Waipawa
# Processing Record 441 | Erenhot
# Processing Record 442 | Zarichne
# Processing Record 443 | Chkalovskoye
# Processing Record 444 | Mangai
# Processing Record 445 | Port Macquarie
# Processing Record 446 | Puerto Escondido
# Processing Record 447 | Meulaboh
# Processing Record 448 | Radovitskiy
# Processing Record 449 | Linares
# Processing Record 450 | Maceió
# Processing Record 451 | Makakilo City
# Processing Record 452 | Porto-Novo
# City not found. Skipping...
# Processing Record 453 | Mischii
# Processing Record 454 | Ingham
# Processing Record 455 | Ginir
# Processing Record 456 | Pacific Grove
# Processing Record 457 | San Juan de los Lagos
# Processing Record 458 | Yulara
# Processing Record 459 | São Paulo de Olivença
# Processing Record 460 | Armidale
# Processing Record 461 | Nemyriv
# Processing Record 462 | Jalu
# City not found. Skipping...
# Processing Record 463 | Zhigansk
# Processing Record 464 | Atar
# Processing Record 465 | Port Augusta
# Processing Record 466 | Marawi
# Processing Record 467 | Pasco
# Processing Record 468 | Bawku
# Processing Record 469 | Shakawe
# Processing Record 470 | Chara
# Processing Record 471 | Muzhi
# Processing Record 472 | Catuday
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 473 | Gualaceo
# Processing Record 474 | Dandong
# Processing Record 475 | San Andrés
# Processing Record 476 | Oranjemund
# Processing Record 477 | Kenora
# Processing Record 478 | Sawtell
# Processing Record 479 | Dingli
# Processing Record 480 | Torbat-e Jām
# Processing Record 481 | Kumul
# Processing Record 482 | Bedēsa
# Processing Record 483 | Pando
# Processing Record 484 | Leonidovo
# Processing Record 485 | Ponta Delgada
# Processing Record 486 | Pimentel
# Processing Record 487 | Kawalu
# Processing Record 488 | Shitanjing
# Processing Record 489 | Verkhoyansk
# Processing Record 490 | Urucará
# Processing Record 491 | Caravelas
# Processing Record 492 | Pudozh
# Processing Record 493 | Tilichiki
# Processing Record 494 | Carutapera
# Processing Record 495 | Tezu
# Processing Record 496 | Tadine
# Processing Record 497 | Gimli
# Processing Record 498 | Airai
# Processing Record 499 | Tumen
# Processing Record 500 | Natal
# Processing Record 501 | Dunmore East
# Processing Record 502 | Nexø
# Processing Record 503 | Vrangel'
# Processing Record 504 | Nuuk
# Processing Record 505 | Ankazoabo
# Processing Record 506 | Warman
# Processing Record 507 | Sørland
# Processing Record 508 | Moa
# Processing Record 509 | Naze
# Processing Record 510 | Tepechitlán
# Processing Record 511 | Coracora
# Processing Record 512 | Lixouri
# City not found. Skipping...
# Processing Record 513 | Lockhart
# Processing Record 514 | Byron Bay
# Processing Record 515 | Dolisie
# Processing Record 516 | Raudeberg
# Processing Record 517 | Baruun-Urt
# Processing Record 518 | Ascension
# Processing Record 519 | Oistins
# Processing Record 520 | Namie
# Processing Record 521 | Itoman
# Processing Record 522 | Madang
# Processing Record 523 | Iroquois Falls
# Processing Record 524 | Miyako
# Processing Record 525 | Severomuysk
# Processing Record 526 | Glendive
# City not found. Skipping...
# Processing Record 527 | Española
# Processing Record 528 | Juneau
# City not found. Skipping...
# Processing Record 529 | Pangai
# Processing Record 530 | San Miguel de Tucumán
# Processing Record 531 | Besuki
# Processing Record 532 | Balashov
# Processing Record 533 | Neenah
# Processing Record 534 | Brownsville
# Processing Record 535 | Morant Bay
# Processing Record 536 | Manokwari
# Processing Record 537 | Umm Kaddadah
# Processing Record 538 | Abhā
# Processing Record 539 | Port Blair
# Processing Record 540 | Prescott
# Processing Record 541 | Killybegs
# Processing Record 542 | Pingzhuang
# City not found. Skipping...
# Processing Record 543 | Broken Hill
# Processing Record 544 | Sabha
# Processing Record 545 | Vitória de Santo Antão
# Processing Record 546 | Vágur
# Processing Record 547 | Maracaçumé
# Processing Record 548 | Opuwo
# Processing Record 549 | Batagay
# Processing Record 550 | Itarema
# Processing Record 551 | Christchurch
# Processing Record 552 | Kulim
# City not found. Skipping...
# Processing Record 553 | Mabaruma
# Processing Record 554 | Lumphat
# Processing Record 555 | Pringsewu
# Processing Record 556 | Mitsamiouli
# City not found. Skipping...
# ----Data Retrieval Complete----

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_dict = {
    "City": city_name,
    "Country": country,
    "Date": date,
    "Latitude": latitude,
    "Longitude": longitude,
    "Max Temperature": max_temperature,
    "Humidity": humidity,
    "Cloudiness": cloudiness,
    "Wind Speed": wind_speed
}

weather_data = pd.DataFrame(weather_dict)
weather_data.count()
# Out:
# City               556
# Country            556
# Date               556
# Latitude           556
# Longitude          556
# Max Temperature    556
# Humidity           556
# Cloudiness         556
# Wind Speed         556
# dtype: int64

# %%
weather_data.head()
# Out:
#         City Country        Date  Latitude  Longitude  Max Temperature  \
# 0       Lata      PT  1583942416     40.16      -8.33            82.00
# 1      Bluff      NZ  1583942416    -46.60     168.33            44.24
# 2   Thompson      CA  1583942416     55.74     -97.86             3.20
# 3       Hilo      US  1583942156     19.73    -155.09            66.20
# 4  Jamestown      US  1583942335     42.10     -79.24            37.99
#
#    Humidity  Cloudiness  Wind Speed
# 0        68          86        6.93
# 1        91          66        5.21
# 2        71          75        2.24
# 3        82          40        4.70
# 4        60          90        5.82

# %%
weather_data.to_csv("./Data/weather_data.csv")

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
#Build Scatter Plot
plt.scatter(weather_data["Latitude"], weather_data["Max Temperature"], facecolors="orange", edgecolor="black", marker="o")

#formatting
plt.title("City Latitude vs Max Temperature (03/11/2020)")
plt.ylabel("Max Temperature (°F)")
plt.xlabel("Latitude")
plt.grid(True)

plt.show()

# Save the figure
plt.savefig("Latitude_vs_Temperature.png")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
#plot for lat vs humidity comparison
plt.scatter(weather_data["Latitude"], weather_data["Humidity"], facecolors="blue", edgecolor="black", marker="o")

#formatting
plt.title("City Latitude vs Humidity (03/11/2020)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Show plot
plt.show()

# Save the figure
plt.savefig("Latitude_vs_Humidity.png")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
#plot for lat vs cloudiness comparison
plt.scatter(weather_data["Latitude"], weather_data["Cloudiness"], facecolors="green", edgecolor="black", marker="o")

#formatting
plt.title("City Latitude vs Cloudiness (03/11/2020)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

plt.show()

# Save the figure
plt.savefig("Latitude_vs_Clouds.png")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
#plot for lat vs wind comparison
plt.scatter(weather_data["Latitude"], weather_data["Wind Speed"], facecolors="yellow", edgecolor = "black", marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs Wind Speed (03/11/2020)")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Show plot
plt.show()

# Save the figure
plt.savefig("Latitude_vs_Wind.png")
